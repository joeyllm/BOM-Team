# %%
# !pip install pyarrow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 48.4 MB/s  0:00:01 eta 0:00:01
# ...

# %% [markdown]
# # Read Data

# %%
import pandas as pd

df = pd.read_parquet("~/data/AUTokens50/part_3.parquet")
df.head()
# Out:
#                                                     text  \
# 6535   Speared man unearthed after 4,000 years\nConst...
# 7763   Kathy Jackson's royal commission revelation\nR...
# 7986   Pessimistic stockmarket predictor Marc Faber. ...
# 9752   Pregnant woman in silhouette\nQueensland’s Chi...
# 10185  The Hawks triumphed in Friday night’s top of t...
#
#                                                     id             dump  \
# 6535   <urn:uuid:bcf9c236-cd4e-49e1-b84d-e10c85b32ef5>  CC-MAIN-2014-42
# 7763   <urn:uuid:8530b4a7-c961-45ea-b011-fa0c12d0bad1>  CC-MAIN-2014-42
# 7986   <urn:uuid:02a21321-e3dd-48ea-bb0d-cda7247af2f1>  CC-MAIN-2014-42
# 9752   <urn:uuid:692f6b2d-725c-44e2-8d85-5da7edd9dfd8>  CC-MAIN-2014-42
# 10185  <urn:uuid:4b27e3ec-8620-4f96-b117-d95cef8dde84>  CC-MAIN-2014-42
#
#                                                      url  \
# 6535   http://www.abc.net.au/news/2007-12-21/speared-...
# 7763   http://www.brisbanetimes.com.au/nsw/health-ser...
# ...

# %% [markdown]
# # Wokring

# %% [markdown]
# ## I am going to print "Hello WOrld"

# %%
print("hello world")
# Out:
# hello world
